# %%
import os
import glob
import pandas as pd
os.chdir(r"C:\Users\ONYIAOCHA\Desktop\Pandas-Analytics-Project")

# %%
files=glob.glob(r'C:\Users\ONYIAOCHA\Desktop\Pandas-Analytics-Project\*.csv')
list=[]
for file in files:
    list.append(pd.read_csv(file))

# %%
df=pd.concat(list, ignore_index =True)

# %%
df
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    692-92-5582      B          Abuja        Member  Female
# 1    351-62-0822      B          Abuja        Member  Female
# 2    529-56-3974      B          Abuja        Member    Male
# 3    299-46-1805      B          Abuja        Member  Female
# 4    319-50-3348      B          Abuja        Normal  Female
# ..           ...    ...            ...           ...     ...
# 995  148-41-7930      C  Port Harcourt        Normal    Male
# 996  189-40-5216      C  Port Harcourt        Normal    Male
# 997  267-62-7380      C  Port Harcourt        Member    Male
# 998  652-49-6720      C  Port Harcourt        Member  Female
# 999  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0        Food and beverages     19742.4         3   2961.36   62188.56
# 1       Fashion accessories      5212.8         4   1042.56   21893.76
# ...

# %%
df.to_csv('XYZ_Supermarket_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unit price     Quantity        Tax 5%          Total           cogs  \
# count   1000.000000  1000.000000   1000.000000    1000.000000    1000.000000
# mean   20041.966800     5.510000   5536.572840  116268.029640  110731.456800
# std     9538.066205     2.923431   4215.177173   88518.720636   84303.543463
# min     3628.800000     1.000000    183.060000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.955000   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.680000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.290000  169686.090000  161605.800000
# max    35985.600000    10.000000  17874.000000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00   5536.572840     6.97270
# std               6.131498e-14   4215.177173     1.71858
# ...

# %% [markdown]
# ### Statistical summary
# * An average total revenue of 116268 Naira was generated per sale.
# * The total revenue generated per sale was within the range; 3844 to 375354.
# * An average tax of 5536.57 was generated per sale.
# * The tax was equal to the gross income. That is, there was no net income.
# * The gross income was 4.76% of the total revenue for each sale.
# * The gross income generated per sale was within the range; 183 to 17874.
# * The customers gave an average shopping experience rating of 6.97 out of 10

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['Time']=pd.to_datetime(df['Time'])

# %%
df['Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['Year']=df['Date'].dt.year

# %%
df['Month']=df['Date'].dt.month

# %%
df['Day']=df['Date'].dt.day

# %%
df['Hour']=df['Time'].dt.hour

# %%
df['Hour'].nunique()
# Out:
# 11

# %%
df['Hour'].unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %%
categorical_columns= [col for col in df.columns if df[col].dtype =="object"]

# %%
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
print(df['City'].unique().tolist())
print("Total Number of unique values in the City Column : {}". format(len(df['City'].unique().tolist())))
# Out:
# ['Abuja', 'Lagos', 'Port Harcourt']
# Total Number of unique values in the City Column : 3

# %%
print(df['Customer type'].unique().tolist())
print("Total Number of unique values in the Customer type Column : {}". format(len(df['Customer type'].unique().tolist())))
# Out:
# ['Member', 'Normal']
# Total Number of unique values in the Customer type Column : 2

# %%
print(df['Gender'].unique().tolist())
print("Total Number of unique values in the Gender Column : {}". format(len(df['Gender'].unique().tolist())))
# Out:
# ['Female', 'Male']
# Total Number of unique values in the Gender Column : 2

# %%
print(df['Product line'].unique().tolist())
print("Total Number of unique values in the Product line Column : {}". format(len(df['Product line'].unique().tolist())))
# Out:
# ['Food and beverages', 'Fashion accessories', 'Electronic accessories', 'Sports and travel', 'Home and lifestyle', 'Health and beauty']
# Total Number of unique values in the Product line Column : 6

# %%
print(df['Payment'].unique().tolist())
print("Total Number of unique values in the Payment Column : {}". format(len(df['Payment'].unique().tolist())))
# Out:
# ['Card', 'Epay', 'Cash']
# Total Number of unique values in the Payment Column : 3

# %%
df['City'].value_counts()
# Out:
# Lagos            340
# Abuja            332
# Port Harcourt    328
# Name: City, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
df['Payment'].value_counts()
# Out:
# Epay    345
# Cash    344
# Card    311
# Name: Payment, dtype: int64

# %%
Cities= df.groupby('City')

# %%
Cities.agg({'gross income':['sum']})
# Out:
#               gross income
#                        sum
# City
# Abuja           1820531.52
# Lagos           1820577.78
# Port Harcourt   1895463.54

# %% [markdown]
# The city with the highest total gross income is Port Harcourt

# %%
Cities.agg({'Rating':['mean']})
# Out:
#                  Rating
#                    mean
# City
# Abuja          6.818072
# Lagos          7.027059
# Port Harcourt  7.072866

# %% [markdown]
# The city with the highest average rating is Port Harcourt

# %%
sns.countplot(x='Branch', data=df).set_title('Number of sales per Branch')
# Out:
# Text(0.5, 1.0, 'Number of sales per Branch')

# %% [markdown]
# Branch A has the highest number of sales

# %%
sns.countplot(x='City', hue= 'Payment', data=df).set_title('Distribution of Payment method per City')
# Out:
# Text(0.5, 1.0, 'Distribution of Payment method per City')

# %%
sns.countplot(x='City',hue='Customer type', data=df).set_title('Distribution of Customer type per City')
# Out:
# Text(0.5, 1.0, 'Distribution of Customer type per City')

# %%
sns.countplot(y='Product line', data=df).set_title('Number of sales per Product line')
# Out:
# Text(0.5, 1.0, 'Number of sales per Product line')

# %% [markdown]
# The highest sold product line is the Fashion Accessories product line, while the least sold product line is the Health & Beauty product line.

# %%
sns.countplot(y='Product line', hue='Payment', data=df).set_title('Distribution of Payment method per Product line')
# Out:
# Text(0.5, 1.0, 'Distribution of Payment method per Product line')

# %%
sns.countplot(x='Payment', hue='Branch', data=df).set_title('Distribution of Branch per Payment method')
# Out:
# Text(0.5, 1.0, 'Distribution of Branch per Payment method')

# %%
sns.countplot(x='Branch', hue='Payment', data=df).set_title('Distribution of Payment method per Branch')
# Out:
# Text(0.5, 1.0, 'Distribution of Payment method per Branch')

# %%
sns.boxplot(x='Branch', y='Rating',data=df).set_title('Distribution of Rating per Branch')
# Out:
# Text(0.5, 1.0, 'Distribution of Rating per Branch')

# %% [markdown]
# The branch with the lowest rating is branch B, which is Abuja city.

# %%
sns.catplot(x='Product line', y='Quantity', hue='Gender', data=df, kind='point', aspect=4).fig.suptitle('Distribution of Quantity and Gender per Product line')
# Out:
# Text(0.5, 0.98, 'Distribution of Quantity and Gender per Product line')

# %%
sns.catplot(x='Product line', y='Total', hue='Gender', data=df, kind='point', aspect=4).fig.suptitle('Distribution of Total price and Gender per Product line')
# Out:
# Text(0.5, 0.98, 'Distribution of Total price and Gender per Product line')

# %%
sns.catplot(x='Product line', y='Unit price', data=df, kind='point', aspect=4).fig.suptitle('Distribution of Unit price per Product line')
# Out:
# Text(0.5, 0.98, 'Distribution of Unit price per Product line')

# %%
sns.catplot(x='Product line', y='Quantity', data=df, kind='point', aspect=4).fig.suptitle('Distribution of Quantity per Product line')
# Out:
# Text(0.5, 0.98, 'Distribution of Quantity per Product line')

# %%
sns.countplot(x='Month', data=df).set_title('Number of Sales per Month')
# Out:
# Text(0.5, 1.0, 'Number of Sales per Month')

# %% [markdown]
# The monthly total number of sales significantly reduced in the month of February.

# %%
sns.countplot(x='Month',hue='Product line', data=df).set_title('Distribution of Product line per Month')
plt.legend(loc='lower left')

# %%
sns.catplot(x='Product line', y='gross income', data=df, kind='point', aspect=4).fig.suptitle('Distribution of Gross income per Product line')
# Out:
# Text(0.5, 0.98, 'Distribution of Gross income per Product line')
